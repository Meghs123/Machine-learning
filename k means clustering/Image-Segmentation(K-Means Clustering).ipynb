# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
# Out:
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\KIIT\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
# !Pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\kiit\anaconda3\lib\site-packages (4.5.1.48)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\kiit\anaconda3\lib\site-packages (from opencv-python) (1.19.5)

# %%
im = cv2.imread('elephant.jpg') # read an image in BGR Format
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
original_image=im.shape
print(im.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-828fc3d34ef0> in <module>
#       1 im = cv2.imread('elephant.jpg') # read an image in BGR Format
#       2 #im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
# ----> 3 original_image=im.shape
#       4 print(im.shape)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
im = cv2.imread('C:/Users/KIIT/Desktop/k_means_image/elephant.jpg') # read an image in BGR Format
im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
original_image=im.shape
print(im.shape)
# Out:
# (330, 500, 3)

# %%
plt.imshow(im)
plt.show()

# %%
all_pixels = im.reshape((330*500, 3))
print(all_pixels.shape)
# Out:
# (165000, 3)

# %%
from sklearn.cluster import KMeans

# %%
km = KMeans(n_clusters=4)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=4)

# %%
centers = km.cluster_centers_
centers = np.array(centers, dtype='uint8')
print(centers)
# Out:
# [[ 98  94 117]
#  [  1   0   1]
#  [174 145 128]
#  [ 37  35  64]]

# %%
plt.figure(0,figsize=(6,2))

i=1

colors = []
for each_col in centers:
    plt.subplot(1,4,i)
    plt.axis('off')
    i+=1
    
    colors.append(each_col)
    
    # Color swatch 
    a = np.zeros((100,100,3), dtype='uint8')
    a[:,:,:] = each_col
    plt.imshow(a)

plt.show()

# %%
new_img = np.zeros((330*500, 3), dtype='uint8')

print(new_img.shape)
# Out:
# (165000, 3)

# %%
colors
# Out:
# [array([ 98,  94, 117], dtype=uint8),
#  array([1, 0, 1], dtype=uint8),
#  array([174, 145, 128], dtype=uint8),
#  array([37, 35, 64], dtype=uint8)]

# %%
km.labels_
# Out:
# array([3, 3, 3, ..., 1, 1, 1])

# %%
for i in range(new_img.shape[0]):
    new_img[i] = colors[km.labels_[i]]
# print(original_image)    
new_img = new_img.reshape((original_image))
# print(new_img.shape)
plt.imshow(new_img)
plt.show()
